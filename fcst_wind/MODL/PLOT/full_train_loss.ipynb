# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
#file_name="loss_var6_e1000_bs8_lr0.009_nf80_pdsame_ks6_dr0.07_dl48_ns1_2101_2104_2201_2204_47105"

df1 = pd.read_csv("../DAOU/LOGF/CNTL/log_var6_e1000_bs8_lr0.009_nf80_pdsame_ks6_dr0.07_dl48_ns1_2101_2104_2201_2204_47105.csv", encoding='utf8', header=0, sep=';')
df2 = pd.read_csv("../DAOU/LOGF/CNTL/log_var6_e1000_bs8_lr0.009_nf50_pdsame_ks3_dr0.07_dl48_ns1_2101_2104_2201_2204_47105.csv", encoding='utf8', header=0, sep=';')
#df1 = df1.set_index('epoch')
#df2 = df2.set_index('epoch')
print(df1)
# Out:
#      epoch      loss
# 0        0  5.822342
# 1        1  0.481316
# 2        2  0.325648
# 3        3  0.287211
# 4        4  0.256482
# ..     ...       ...
# 995    995  0.001039
# 996    996  0.000977
# 997    997  0.000907
# 998    998  0.000943
# 999    999  0.000956
#
# [1000 rows x 2 columns]

# %%
df1.plot(kind='line', ylim=(0, 1), xlim=(0, 1000))
df2.plot(kind='line', ylim=(0, 1), xlim=(0, 1000))
# Out:
# <Axes: >

# %%
df1.plot(kind='line', ylim=(0, 0.005), xlim=(0, 1000))
df2.plot(kind='line', ylim=(0, 0.005), xlim=(0, 1000))
#df.plot(kind='line', ylim=(0, 1), xlim=(0, 50))
# Out:
# <Axes: >
