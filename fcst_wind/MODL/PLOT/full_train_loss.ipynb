# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
file_name="loss_var6_e1000_bs8_lr0.009_nf80_pdsame_ks6_dr0.07_dl48_ns1_2101_2104_2201_2204_47105"

df = pd.read_csv("../DAOU/LOGF/CNTL/log_var6_e1000_bs8_lr0.009_nf80_pdsame_ks6_dr0.07_dl48_ns1_2101_2104_2201_2204_47105.csv", encoding='utf8', header=0, sep=';')
df = df.set_index('epoch')
print(df)
# Out:
#            loss
# epoch
# 0      5.219960
# 1      0.607829
# 2      0.352222
# 3      0.329846
# 4      0.211235
# ...         ...
# 995    0.000717
# 996    0.000779
# 997    0.000858
# 998    0.000809
# 999    0.000713
#
# [1000 rows x 1 columns]

# %%
df.plot(kind='line', ylim=(0, 1), xlim=(0, 1000))
# Out:
# <Axes: xlabel='epoch'>

# %%
#df.plot(kind='line', ylim=(0, 0.005), xlim=(0, 1000))
df.plot(kind='line', ylim=(0, 1), xlim=(0, 50))
# Out:
# <Axes: xlabel='epoch'>
